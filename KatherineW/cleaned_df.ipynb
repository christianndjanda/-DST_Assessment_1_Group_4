# %%
import pandas as pd

df = pd.read_pickle('my_data.pkl')

# %%
df.head(10)
# Out:
#          id  loan_amnt        term  int_rate  installment grade emp_length  \
# 0  66615254     7200.0   36 months     17.27       257.67     D    9 years
# 1  68366850    16000.0   36 months      5.32       481.84     A    8 years
# 2  68406994     8000.0   36 months      7.91       250.36     A    5 years
# 3  68577378    10000.0   36 months      8.49       315.63     B    4 years
# 4  68596525    24000.0   60 months     13.99       558.32     C  10+ years
# 5  68446125    16075.0   36 months     12.88       540.71     C    3 years
# 6  68615524    16000.0   60 months     12.88       363.07     C  10+ years
# 7  68484474    30000.0   36 months     12.88      1009.09     C    3 years
# 8  68406347    15000.0   36 months     15.77       525.66     D  10+ years
# 9  68526025    12000.0   36 months     14.85       415.11     C   < 1 year
#
#   home_ownership  annual_inc verification_status  ...             purpose  \
# ...

# %%
df.shape
# Out:
# (12940, 21)
